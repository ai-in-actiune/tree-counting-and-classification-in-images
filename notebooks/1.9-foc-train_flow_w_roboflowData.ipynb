# %% [markdown]
# 1. Download dataset from roboflow
# 1. Predict and select the images to be manually labeled/reviewed
# 1. Upload them to roboflow

# %%
! pip install -r /content/drive/MyDrive/vork/ML/trees/tree-counting-and-classification-in-images/requirements.txt
# ! pip install --upgrade opencv-python setuptools==59.5.0 albumentations==1.0.3
! pip install roboflow

# %%
! export PROJ_SRC_PATH=/content/drive/MyDrive/vork/ML/trees/tree-counting-and-classification-in-images/src/

# %%
PROJ_SRC_PATH="/content/drive/MyDrive/vork/ML/trees/tree-counting-and-classification-in-images/src/"

# %%
! python $PROJ_SRC_PATH/train_flow.py \
-cfg $PROJ_SRC_PATH/data/config/train_config.cfg \
--pretrained_model_path /content/drive/MyDrive/vork/ML/trees/training/plaiul/deepforest_iter2 \
--model_output_folder_path /content/drive/MyDrive/vork/ML/trees/training/plaiul/roboflow
